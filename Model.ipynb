# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
# 1. SETUP DATA AUGMENTATION (Helps prevent overfitting)
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

# %%
# Load data (Replace 'path_to_data' with your actual directory)
train_generator = train_datagen.flow_from_directory(
    './chest_xray/chest_xray/train',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 5216 images belonging to 2 classes.

# %%
import os
path = './chest_xray/chest_xray/train'
if os.path.exists(path):
    print("Folders found:", os.listdir(path))
else:
    print(f"Error: The path '{path}' does not exist!")
# Out:
# Folders found: ['.DS_Store', 'NORMAL', 'PNEUMONIA']

# %%
# 2. BUILD THE MODEL USING TRANSFER LEARNING
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False, 
    weights='imagenet'
)

# %%
base_model.trainable = False  # Freeze the pre-trained weights

# %%
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(1, activation='sigmoid') # Binary output: Normal vs Pneumonia
])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'Precision', 'Recall'])

# %%
# 3. TRAIN THE MODEL
history = model.fit(train_generator, epochs=10)
# Out:
# Epoch 1/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 194s 1s/step - Precision: 0.9269 - Recall: 0.9394 - accuracy: 0.8999 - loss: 0.2309
# Epoch 2/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 157s 960ms/step - Precision: 0.9588 - Recall: 0.9543 - accuracy: 0.9356 - loss: 0.1568
# Epoch 3/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - Precision: 0.9596 - Recall: 0.9574 - accuracy: 0.9385 - loss: 0.1440
# Epoch 4/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 195s 1s/step - Precision: 0.9614 - Recall: 0.9644 - accuracy: 0.9448 - loss: 0.1356
# Epoch 5/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - Precision: 0.9680 - Recall: 0.9677 - accuracy: 0.9523 - loss: 0.1206
# Epoch 6/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 146s 895ms/step - Precision: 0.9715 - Recall: 0.9688 - accuracy: 0.9557 - loss: 0.1167
# Epoch 7/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 147s 899ms/step - Precision: 0.9676 - Recall: 0.9695 - accuracy: 0.9532 - loss: 0.1160
# Epoch 8/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 160s 982ms/step - Precision: 0.9691 - Recall: 0.9703 - accuracy: 0.9549 - loss: 0.1242
# Epoch 9/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 166s 1s/step - Precision: 0.9724 - Recall: 0.9737 - accuracy: 0.9599 - loss: 0.1102
# Epoch 10/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 180s 1s/step - Precision: 0.9663 - Recall: 0.9683 - accuracy: 0.9513 - loss: 0.1143

# %%
# 4. SAVE THE MODEL
#model.save('pneumonia_detection_model.h5')
model.save('pneumonia_detection_model.keras')
print("Model Saved!")
# Out:
# Model Saved!
